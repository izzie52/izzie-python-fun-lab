# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,37,25,68])

# %%
plt.plot([4,9,20,70],[3,39.4,20,70])

# %%
X = [1.2,6.6,8.9,10]
Y = [90,23,6.7,73]

# %%
plt.plot(X,Y)

# %%
plt.scatter(X,Y)

# %%
np.random.randn(7)
# Out:
# array([-0.77515947, -0.20174292,  0.86312319, -0.47663692, -0.7270506 ,
#        -0.24213843, -1.90294195])

# %%
plt.plot(np.random.randn(100))

# %%
x = np.linspace(0, 10, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
np.pi
# Out:
# 3.141592653589793
